# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("quasars_dr7and9.csv")
df.head()
# Out:
#           SDSS_NAME_1      RA_1     DEC_1   THING_ID  PLATE_1  MJD_1  FIBERID  \
# 0  000042.90+005539.5  0.178757  0.927643  116880826     4216  55477      758
# 1  000046.42+011420.8  0.193434  1.239117  124435173     4216  55477      742
# 2  000051.56+001202.5  0.214857  0.200716   96841458     4216  55477      778
# 3  000053.17-001732.9  0.221547 -0.292490   87838295     4216  55477      228
# 4  000054.95+010143.4  0.228999  1.028727  116879225     4296  55499      322
#
#     Z_VI    Z_PIPE  ERR_ZPIPE  ...  LOGBH_MGII_VO09_ERR  LOGBH_MGII_S10  \
# 0  0.950  0.951742   0.000121  ...             0.075954        8.844193
# 1  3.730  3.758828  -1.000000  ...            -1.000000        0.000000
# 2  3.865  3.895332   0.000538  ...            -1.000000        0.000000
# 3  2.759  2.758672   0.000152  ...            -1.000000        0.000000
# 4  1.459  1.461712   0.000229  ...             0.191151        9.107222
#
# ...

# %%
z = df[["Z_VI"]].values.flatten()
dr7_mag = df[["MI_Z2"]].values.flatten()
dr9_mag = df[["MI"]].values.flatten()

# %%
fig = plt.figure(figsize=(10,10))
plt.hist([dr7_mag, dr9_mag], histtype="step", linewidth=4, bins="scott")
plt.xlim(-33, -20)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(z, dr7_mag, s=1)
plt.scatter(z, dr9_mag, s=1)
plt.ylim(-32, plt.gca().get_ylim()[1])
# Out:
# (-32.0, -20.13720134496006)

# %%
fig = plt.figure(figsize=(10,10))
plt.hist(dr7_mag-dr9_mag, histtype="step", linewidth=4, bins="scott")
plt.xlim(-1, 1)
plt.show()
